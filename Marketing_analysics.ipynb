# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re


df = pd.read_csv("/content/marketing_data.csv")

# %% [markdown]
# # New Section

# %%
df.head()
# Out:
#       ID  Year_Birth   Education  ... Response Complain  Country
# 0   1826        1970  Graduation  ...        1        0       SP
# 1      1        1961  Graduation  ...        1        0       CA
# 2  10476        1958  Graduation  ...        0        0       US
# 3   1386        1967  Graduation  ...        0        0      AUS
# 4   5371        1989  Graduation  ...        1        0       SP
#
# [5 rows x 28 columns]

# %%
df=df.rename({'Incom':'Income'},axis=1)
df.head()
# Out:
#       ID  Year_Birth   Education  ... Response Complain  Country
# 0   1826        1970  Graduation  ...        1        0       SP
# 1      1        1961  Graduation  ...        1        0       CA
# 2  10476        1958  Graduation  ...        0        0       US
# 3   1386        1967  Graduation  ...        0        0      AUS
# 4   5371        1989  Graduation  ...        1        0       SP
#
# [5 rows x 28 columns]

# %%
df
# Out:
#          ID  Year_Birth   Education  ... Response Complain  Country
# 0      1826        1970  Graduation  ...        1        0       SP
# 1         1        1961  Graduation  ...        1        0       CA
# 2     10476        1958  Graduation  ...        0        0       US
# 3      1386        1967  Graduation  ...        0        0      AUS
# 4      5371        1989  Graduation  ...        1        0       SP
# ...     ...         ...         ...  ...      ...      ...      ...
# 2235  10142        1976         PhD  ...        0        0       US
# 2236   5263        1977    2n Cycle  ...        0        0       SP
# 2237     22        1976  Graduation  ...        0        0       SP
# 2238    528        1978  Graduation  ...        0        0      IND
# 2239   4070        1969         PhD  ...        1        0       CA
#
# [2240 rows x 28 columns]

# %%
print (df.columns.tolist())
# Out:
# ['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country']

# %%
df=df[["Year_Birth","Education","Marital_Status"," Income ","Kidhome","Teenhome","Recency","MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts","MntGoldProds"]]
df
# Out:
#       Year_Birth   Education  ... MntSweetProducts MntGoldProds
# 0           1970  Graduation  ...              189          218
# 1           1961  Graduation  ...                0           37
# 2           1958  Graduation  ...                2           30
# 3           1967  Graduation  ...                0            0
# 4           1989  Graduation  ...                0           34
# ...          ...         ...  ...              ...          ...
# 2235        1976         PhD  ...               48           78
# 2236        1977    2n Cycle  ...                8           16
# 2237        1976  Graduation  ...                5           14
# 2238        1978  Graduation  ...              165           63
# 2239        1969         PhD  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df=df[df['MntWines'].notnull()]
df
# Out:
#       Year_Birth   Education  ... MntSweetProducts MntGoldProds
# 0           1970  Graduation  ...              189          218
# 1           1961  Graduation  ...                0           37
# 2           1958  Graduation  ...                2           30
# 3           1967  Graduation  ...                0            0
# 4           1989  Graduation  ...                0           34
# ...          ...         ...  ...              ...          ...
# 2235        1976         PhD  ...               48           78
# 2236        1977    2n Cycle  ...                8           16
# 2237        1976  Graduation  ...                5           14
# 2238        1978  Graduation  ...              165           63
# 2239        1969         PhD  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df=df[df['MntFruits'].notnull()]
df
# Out:
#       Year_Birth   Education  ... MntSweetProducts MntGoldProds
# 0           1970  Graduation  ...              189          218
# 1           1961  Graduation  ...                0           37
# 2           1958  Graduation  ...                2           30
# 3           1967  Graduation  ...                0            0
# 4           1989  Graduation  ...                0           34
# ...          ...         ...  ...              ...          ...
# 2235        1976         PhD  ...               48           78
# 2236        1977    2n Cycle  ...                8           16
# 2237        1976  Graduation  ...                5           14
# 2238        1978  Graduation  ...              165           63
# 2239        1969         PhD  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df=df[df['MntMeatProducts'].notnull()]
df
# Out:
#       Year_Birth   Education  ... MntSweetProducts MntGoldProds
# 0           1970  Graduation  ...              189          218
# 1           1961  Graduation  ...                0           37
# 2           1958  Graduation  ...                2           30
# 3           1967  Graduation  ...                0            0
# 4           1989  Graduation  ...                0           34
# ...          ...         ...  ...              ...          ...
# 2235        1976         PhD  ...               48           78
# 2236        1977    2n Cycle  ...                8           16
# 2237        1976  Graduation  ...                5           14
# 2238        1978  Graduation  ...              165           63
# 2239        1969         PhD  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df=df[df['MntFishProducts'].notnull()]
df
# Out:
#       Year_Birth   Education  ... MntSweetProducts MntGoldProds
# 0           1970  Graduation  ...              189          218
# 1           1961  Graduation  ...                0           37
# 2           1958  Graduation  ...                2           30
# 3           1967  Graduation  ...                0            0
# 4           1989  Graduation  ...                0           34
# ...          ...         ...  ...              ...          ...
# 2235        1976         PhD  ...               48           78
# 2236        1977    2n Cycle  ...                8           16
# 2237        1976  Graduation  ...                5           14
# 2238        1978  Graduation  ...              165           63
# 2239        1969         PhD  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df=df[df['MntSweetProducts'].notnull()]
df
# Out:
#       Year_Birth   Education  ... MntSweetProducts MntGoldProds
# 0           1970  Graduation  ...              189          218
# 1           1961  Graduation  ...                0           37
# 2           1958  Graduation  ...                2           30
# 3           1967  Graduation  ...                0            0
# 4           1989  Graduation  ...                0           34
# ...          ...         ...  ...              ...          ...
# 2235        1976         PhD  ...               48           78
# 2236        1977    2n Cycle  ...                8           16
# 2237        1976  Graduation  ...                5           14
# 2238        1978  Graduation  ...              165           63
# 2239        1969         PhD  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df=df[df['MntGoldProds'].notnull()]
df
# Out:
#       Year_Birth   Education  ... MntSweetProducts MntGoldProds
# 0           1970  Graduation  ...              189          218
# 1           1961  Graduation  ...                0           37
# 2           1958  Graduation  ...                2           30
# 3           1967  Graduation  ...                0            0
# 4           1989  Graduation  ...                0           34
# ...          ...         ...  ...              ...          ...
# 2235        1976         PhD  ...               48           78
# 2236        1977    2n Cycle  ...                8           16
# 2237        1976  Graduation  ...                5           14
# 2238        1978  Graduation  ...              165           63
# 2239        1969         PhD  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 0 to 2239
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year_Birth        2240 non-null   int64
#  1   Education         2240 non-null   object
#  2   Marital_Status    2240 non-null   object
#  3    Income           2216 non-null   object
#  4   Kidhome           2240 non-null   int64
#  5   Teenhome          2240 non-null   int64
#  6   Recency           2240 non-null   int64
#  7   MntWines          2240 non-null   int64
#  8   MntFruits         2240 non-null   int64
#  9   MntMeatProducts   2240 non-null   int64
#  10  MntFishProducts   2240 non-null   int64
#  11  MntSweetProducts  2240 non-null   int64
#  12  MntGoldProds      2240 non-null   int64
# dtypes: int64(10), object(3)
# memory usage: 245.0+ KB

# %%
cat=df['Education']
cat
# Out:
# 0       Graduation
# 1       Graduation
# 2       Graduation
# 3       Graduation
# 4       Graduation
#            ...
# 2235           PhD
# 2236      2n Cycle
# 2237    Graduation
# 2238    Graduation
# 2239           PhD
# Name: Education, Length: 2240, dtype: object

# %%
bat=df['Marital_Status']
bat
# Out:
# 0       Divorced
# 1         Single
# 2        Married
# 3       Together
# 4         Single
#           ...
# 2235    Divorced
# 2236     Married
# 2237    Divorced
# 2238     Married
# 2239     Married
# Name: Marital_Status, Length: 2240, dtype: object

# %% [markdown]
# def filter_ferver_people(categeory,threshold):
#      catregeory_map={}
#      for i in range(len(categeory)):
#          if categeory[i]>=99:
#             categeory[i]=1
#          else:
#             categeory[i]=0
#      return categeory

# %%
def filter_education(categeory,threshold1,threshold2,threshold3):
     catregeory_map={}
     for i in range(len(categeory)):
         if categeory[i]==threshold1:  
            categeory[i]=0
         elif categeory[i]==threshold2:
            categeory[i]=1 
         elif categeory[i]==threshold3:
            categeory[i]=2 
         else:
            categeory[i]=3      
     return categeory

# %%
threshold1="Graduation"
threshold2="PhD"
threshold3="2n Cycle"
filetered_data=filter_education(cat,threshold1,threshold2,threshold3)
filetered_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# ...

# %%
def filter_martial_status(categeory,thres1,thres2,thres3):
     catregeory_map={}
     for i in range(len(categeory)):
         if categeory[i]==thres1:  
            categeory[i]=0
         elif categeory[i]==thres2:
            categeory[i]=1 
         elif categeory[i]==thres3:
            categeory[i]=2 
         else:
            categeory[i]=3      
     return categeory

# %%
thres1="Divorced"
thres2="Single"
thres3="Together"
fil_data=filter_martial_status(bat,thres1,thres2,thres3)
fil_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
df['Education']= filetered_data
df
# Out:
#       Year_Birth Education  ... MntSweetProducts MntGoldProds
# 0           1970         0  ...              189          218
# 1           1961         0  ...                0           37
# 2           1958         0  ...                2           30
# 3           1967         0  ...                0            0
# 4           1989         0  ...                0           34
# ...          ...       ...  ...              ...          ...
# 2235        1976         1  ...               48           78
# 2236        1977         2  ...                8           16
# 2237        1976         0  ...                5           14
# 2238        1978         0  ...              165           63
# 2239        1969         1  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df['Marital_Status']= fil_data
df
# Out:
#       Year_Birth Education  ... MntSweetProducts MntGoldProds
# 0           1970         0  ...              189          218
# 1           1961         0  ...                0           37
# 2           1958         0  ...                2           30
# 3           1967         0  ...                0            0
# 4           1989         0  ...                0           34
# ...          ...       ...  ...              ...          ...
# 2235        1976         1  ...               48           78
# 2236        1977         2  ...                8           16
# 2237        1976         0  ...                5           14
# 2238        1978         0  ...              165           63
# 2239        1969         1  ...                0          144
#
# [2240 rows x 13 columns]

# %%
df=df[df[" Income "].notnull()]
df
# Out:
#       Year_Birth Education  ... MntSweetProducts MntGoldProds
# 0           1970         0  ...              189          218
# 1           1961         0  ...                0           37
# 2           1958         0  ...                2           30
# 3           1967         0  ...                0            0
# 4           1989         0  ...                0           34
# ...          ...       ...  ...              ...          ...
# 2235        1976         1  ...               48           78
# 2236        1977         2  ...                8           16
# 2237        1976         0  ...                5           14
# 2238        1978         0  ...              165           63
# 2239        1969         1  ...                0          144
#
# [2216 rows x 13 columns]

# %%
sub=df[" Income "]
sub
# Out:
# 0       $84,835.00
# 1       $57,091.00
# 2       $67,267.00
# 3       $32,474.00
# 4       $21,474.00
#            ...
# 2235    $66,476.00
# 2236    $31,056.00
# 2237    $46,310.00
# 2238    $65,819.00
# 2239    $94,871.00
# Name:  Income , Length: 2216, dtype: object

# %%
    
catregeory_map={}
the=[]
for x in sub:   
     x=str(x)
     the.append(x)
print(the)
# Out:
# ['$84,835.00 ', '$57,091.00 ', '$67,267.00 ', '$32,474.00 ', '$21,474.00 ', '$71,691.00 ', '$63,564.00 ', '$44,931.00 ', '$65,324.00 ', '$65,324.00 ', '$81,044.00 ', '$62,499.00 ', '$67,786.00 ', '$26,872.00 ', '$4,428.00 ', '$54,809.00 ', '$54,809.00 ', '$32,173.00 ', '$47,823.00 ', '$30,523.00 ', '$36,634.00 ', '$43,456.00 ', '$40,662.00 ', '$49,544.00 ', '$57,731.00 ', '$33,168.00 ', '$54,450.00 ', '$54,450.00 ', '$35,340.00 ', '$73,170.00 ', '$65,808.00 ', '$79,529.00 ', '$34,578.00 ', '$46,374.00 ', '$18,351.00 ', '$95,169.00 ', '$65,370.00 ', '$39,228.00 ', '$84,865.00 ', '$61,314.00 ', '$21,359.00 ', '$66,465.00 ', '$81,698.00 ', '$39,146.00 ', '$25,959.00 ', '$64,260.00 ', '$32,300.00 ', '$74,806.00 ', '$72,967.00 ', '$48,904.00 ', '$14,796.00 ', '$66,991.00 ', '$52,195.00 ', '$90,369.00 ', '$18,393.00 ', '$47,139.00 ', '$38,576.00 ', '$61,905.00 ', '$83,715.00 ', '$60,597.00 ', '$6,560.00 ', '$48,330.00 ', '$38,236.00 ', '$22,701.00 ', '$53,367.00 ', '$34,728.00 ', '$63,915.
# ...

# %%
final=[]
for x in the:
    fin=x.split("$")
    final.append(fin[1])


print(final)
# Out:
# ['84,835.00 ', '57,091.00 ', '67,267.00 ', '32,474.00 ', '21,474.00 ', '71,691.00 ', '63,564.00 ', '44,931.00 ', '65,324.00 ', '65,324.00 ', '81,044.00 ', '62,499.00 ', '67,786.00 ', '26,872.00 ', '4,428.00 ', '54,809.00 ', '54,809.00 ', '32,173.00 ', '47,823.00 ', '30,523.00 ', '36,634.00 ', '43,456.00 ', '40,662.00 ', '49,544.00 ', '57,731.00 ', '33,168.00 ', '54,450.00 ', '54,450.00 ', '35,340.00 ', '73,170.00 ', '65,808.00 ', '79,529.00 ', '34,578.00 ', '46,374.00 ', '18,351.00 ', '95,169.00 ', '65,370.00 ', '39,228.00 ', '84,865.00 ', '61,314.00 ', '21,359.00 ', '66,465.00 ', '81,698.00 ', '39,146.00 ', '25,959.00 ', '64,260.00 ', '32,300.00 ', '74,806.00 ', '72,967.00 ', '48,904.00 ', '14,796.00 ', '66,991.00 ', '52,195.00 ', '90,369.00 ', '18,393.00 ', '47,139.00 ', '38,576.00 ', '61,905.00 ', '83,715.00 ', '60,597.00 ', '6,560.00 ', '48,330.00 ', '38,236.00 ', '22,701.00 ', '53,367.00 ', '34,728.00 ', '63,915.00 ', '82,504.00 ', '38,578.00 ', '38,578.00 ', '79,174.00 ', '81,9
# ...

# %%
last=[]

for x in final:
   las=x.split(" ")
   last.append(las[0])

print(last)
# Out:
# ['84,835.00', '57,091.00', '67,267.00', '32,474.00', '21,474.00', '71,691.00', '63,564.00', '44,931.00', '65,324.00', '65,324.00', '81,044.00', '62,499.00', '67,786.00', '26,872.00', '4,428.00', '54,809.00', '54,809.00', '32,173.00', '47,823.00', '30,523.00', '36,634.00', '43,456.00', '40,662.00', '49,544.00', '57,731.00', '33,168.00', '54,450.00', '54,450.00', '35,340.00', '73,170.00', '65,808.00', '79,529.00', '34,578.00', '46,374.00', '18,351.00', '95,169.00', '65,370.00', '39,228.00', '84,865.00', '61,314.00', '21,359.00', '66,465.00', '81,698.00', '39,146.00', '25,959.00', '64,260.00', '32,300.00', '74,806.00', '72,967.00', '48,904.00', '14,796.00', '66,991.00', '52,195.00', '90,369.00', '18,393.00', '47,139.00', '38,576.00', '61,905.00', '83,715.00', '60,597.00', '6,560.00', '48,330.00', '38,236.00', '22,701.00', '53,367.00', '34,728.00', '63,915.00', '82,504.00', '38,578.00', '38,578.00', '79,174.00', '81,975.00', '43,263.00', '27,242.00', '76,445.00', '75,276.00', '34,213.00'
# ...

# %%
fin=[]

for x in last:
    camma=x.split(",")
    fin_camma=camma[0]+camma[1]
    fin.append(fin_camma)

print(fin)
# Out:
# ['84835.00', '57091.00', '67267.00', '32474.00', '21474.00', '71691.00', '63564.00', '44931.00', '65324.00', '65324.00', '81044.00', '62499.00', '67786.00', '26872.00', '4428.00', '54809.00', '54809.00', '32173.00', '47823.00', '30523.00', '36634.00', '43456.00', '40662.00', '49544.00', '57731.00', '33168.00', '54450.00', '54450.00', '35340.00', '73170.00', '65808.00', '79529.00', '34578.00', '46374.00', '18351.00', '95169.00', '65370.00', '39228.00', '84865.00', '61314.00', '21359.00', '66465.00', '81698.00', '39146.00', '25959.00', '64260.00', '32300.00', '74806.00', '72967.00', '48904.00', '14796.00', '66991.00', '52195.00', '90369.00', '18393.00', '47139.00', '38576.00', '61905.00', '83715.00', '60597.00', '6560.00', '48330.00', '38236.00', '22701.00', '53367.00', '34728.00', '63915.00', '82504.00', '38578.00', '38578.00', '79174.00', '81975.00', '43263.00', '27242.00', '76445.00', '75276.00', '34213.00', '72335.00', '79143.00', '27469.00', '68695.00', '68695.00', '50388.00', '77
# ...

# %%
dot=[]

for x in fin:
   do=x.split(".")
   dot.append(do[0])

print(dot)
# Out:
# ['84835', '57091', '67267', '32474', '21474', '71691', '63564', '44931', '65324', '65324', '81044', '62499', '67786', '26872', '4428', '54809', '54809', '32173', '47823', '30523', '36634', '43456', '40662', '49544', '57731', '33168', '54450', '54450', '35340', '73170', '65808', '79529', '34578', '46374', '18351', '95169', '65370', '39228', '84865', '61314', '21359', '66465', '81698', '39146', '25959', '64260', '32300', '74806', '72967', '48904', '14796', '66991', '52195', '90369', '18393', '47139', '38576', '61905', '83715', '60597', '6560', '48330', '38236', '22701', '53367', '34728', '63915', '82504', '38578', '38578', '79174', '81975', '43263', '27242', '76445', '75276', '34213', '72335', '79143', '27469', '68695', '68695', '50388', '77622', '46102', '31859', '23830', '24639', '71604', '27255', '55375', '77037', '24163', '69476', '72063', '58646', '58646', '47570', '80011', '54998', '60200', '63211', '48432', '48432', '48432', '62845', '62845', '65220', '74214', '96547', '53863', 
# ...

# %%
final_list=[]
for x in dot:
  x=int(x)
  final_list.append(x)
print(final_list)
# Out:
# [84835, 57091, 67267, 32474, 21474, 71691, 63564, 44931, 65324, 65324, 81044, 62499, 67786, 26872, 4428, 54809, 54809, 32173, 47823, 30523, 36634, 43456, 40662, 49544, 57731, 33168, 54450, 54450, 35340, 73170, 65808, 79529, 34578, 46374, 18351, 95169, 65370, 39228, 84865, 61314, 21359, 66465, 81698, 39146, 25959, 64260, 32300, 74806, 72967, 48904, 14796, 66991, 52195, 90369, 18393, 47139, 38576, 61905, 83715, 60597, 6560, 48330, 38236, 22701, 53367, 34728, 63915, 82504, 38578, 38578, 79174, 81975, 43263, 27242, 76445, 75276, 34213, 72335, 79143, 27469, 68695, 68695, 50388, 77622, 46102, 31859, 23830, 24639, 71604, 27255, 55375, 77037, 24163, 69476, 72063, 58646, 58646, 47570, 80011, 54998, 60200, 63211, 48432, 48432, 48432, 62845, 62845, 65220, 74214, 96547, 53863, 50447, 37716, 45203, 37368, 67225, 65104, 65104, 81698, 70566, 69096, 71434, 33039, 33039, 46610, 49967, 53359, 49505, 68657, 72071, 72071, 59235, 21994, 21994, 69209, 31928, 74004, 30390, 21355, 26304, 85710, 102692, 5835
# ...

# %%
length=len(df[" Income "])
length
# Out:
# 2216

# %%
  df[" Income "]=final_list
  df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Year_Birth Education  ... MntSweetProducts  MntGoldProds
# 0           1970         0  ...              189           218
# 1           1961         0  ...                0            37
# 2           1958         0  ...                2            30
# 3           1967         0  ...                0             0
# 4           1989         0  ...                0            34
# ...          ...       ...  ...              ...           ...
# 2235        1976         1  ...               48            78
# 2236        1977         2  ...                8            16
# ...

# %%
df
# Out:
#       Year_Birth Education  ... MntSweetProducts  MntGoldProds
# 0           1970         0  ...              189           218
# 1           1961         0  ...                0            37
# 2           1958         0  ...                2            30
# 3           1967         0  ...                0             0
# 4           1989         0  ...                0            34
# ...          ...       ...  ...              ...           ...
# 2235        1976         1  ...               48            78
# 2236        1977         2  ...                8            16
# 2237        1976         0  ...                5            14
# 2238        1978         0  ...              165            63
# 2239        1969         1  ...                0           144
#
# [2216 rows x 13 columns]

# %%
y=df["MntWines"]
y
# Out:
# 0       189
# 1       464
# 2       134
# 3        10
# 4         6
#        ...
# 2235    372
# 2236      5
# 2237    185
# 2238    267
# 2239    169
# Name: MntWines, Length: 2216, dtype: int64

# %%
 x=df.drop(columns=['MntWines','MntFruits','MntMeatProducts',"MntFishProducts","MntSweetProducts","MntGoldProds"])
 x
# Out:
#       Year_Birth Education Marital_Status   Income   Kidhome  Teenhome  Recency
# 0           1970         0              0     84835        0         0        0
# 1           1961         0              1     57091        0         0        0
# 2           1958         0              3     67267        0         1        0
# 3           1967         0              2     32474        1         1        0
# 4           1989         0              1     21474        1         0        0
# ...          ...       ...            ...       ...      ...       ...      ...
# 2235        1976         1              0     66476        0         1       99
# 2236        1977         2              3     31056        1         0       99
# 2237        1976         0              0     46310        1         0       99
# 2238        1978         0              3     65819        0         0       99
# 2239        1969         1              3     94871        0         2       99
#
# ...

# %%
y
# Out:
# 0       189
# 1       464
# 2       134
# 3        10
# 4         6
#        ...
# 2235    372
# 2236      5
# 2237    185
# 2238    267
# 2239    169
# Name: MntWines, Length: 2216, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
liner_reg=LinearRegression()
liner_reg.fit(x,y.values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=liner_reg.predict(x)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
import numpy as np
error=np.sqrt(mean_squared_error(y,y_pred))

# %%
error
# Out:
# 258.39021990490295

# %%
from sklearn.tree import DecisionTreeRegressor
dec_tree=DecisionTreeRegressor(random_state=0)
dec_tree.fit(x,y.values)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
y_pred1=dec_tree.predict(x)

# %%
error=np.sqrt(mean_squared_error(y,y_pred1))

# %%
error
# Out:
# 0.0

# %%
from sklearn.ensemble import RandomForestRegressor
ran_tree=RandomForestRegressor(random_state=0)
ran_tree.fit(x,y.values)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred2=ran_tree.predict(x)

# %%
error=np.sqrt(mean_squared_error(y,y_pred2))

# %%
error
# Out:
# 79.86494741293428

# %%
x=np.array([[19811,0,20000,0,0,0,0]])
x
# Out:
# array([[19811,     0, 20000,     0,     0,     0,     0]])

# %%
y_pred=dec_tree.predict(x)
y_pred
# Out:
# array([16.])

# %%
import pickle

# %%
pickle.dump(dec_tree,open('pickel_model.pkl','wb'))

model=pickle.load(open('pickel_model.pkl','rb'))

# %%
y_pred=dec_tree.predict(x)
print(y_pred)
# Out:
# [16.]
